# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.sparse import csr_matrix
from mpl_toolkits.axes_grid1 import make_axes_locatable
from sklearn.cluster import KMeans
from sklearn.metrics import mean_squared_error
import itertools
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.externals import joblib

# %%
#load files for analysis
beer = pd.read_csv('10k_filtered.csv')
beer.columns
# Out:
# Index(['Unnamed: 0', 'brewery_id', 'brewery_name', 'review_time',
#        'review_overall', 'review_aroma', 'review_appearance',
#        'review_profilename', 'beer_style', 'review_palate', 'review_taste',
#        'beer_name', 'beer_abv', 'beer_beerid', 'main_style'],
#       dtype='object')

# %%
beer.head()
# Out:
#    Unnamed: 0  brewery_id          brewery_name  review_time  review_overall  \
# 0           0       10099  Dogfish Head Brewery   1266775164             4.0
# 1           1       10099  Dogfish Head Brewery   1296628385             4.0
# 2           2       10099  Dogfish Head Brewery   1250389086             4.0
# 3           3       10099  Dogfish Head Brewery   1230224468             5.0
# 4           4       10099  Dogfish Head Brewery   1229312994             4.0
#
#    review_aroma  review_appearance review_profilename  \
# 0           4.5                4.5            DmanGTR
# 1           4.0                4.0         nickadams2
# 2           4.0                4.0           kegger22
# 3           5.0                5.0       fairway31533
# 4           4.5                4.0               Bung
#
#                        beer_style  review_palate  review_taste      beer_name  \
# 0  American Double / Imperial IPA            4.5           4.5  90 Minute IPA
# 1  American Double / Imperial IPA            3.5           4.0  90 Minute IPA
# 2  American Double / Imperial IPA            4.0           4.5  90 Minute IPA
# 3  American Double / Imperial IPA            5.0           5.0  90 Minute IPA
# 4  American Double / Imperial IPA            4.0           4.0  90 Minute IPA
#
#    beer_abv  beer_beerid       main_style
# 0       9.0         2093  India Pale Ales
# 1       9.0         2093  India Pale Ales
# 2       9.0         2093  India Pale Ales
# 3       9.0         2093  India Pale Ales
# 4       9.0         2093  India Pale Ales

# %%
len(beer.review_profilename.unique())
# Out:
# 32141

# %% [markdown]
# # Data Cleaning 10 or more reviews

# %%
grouped = beer.groupby(['review_profilename','beer_name']).mean().round(2)['review_overall']
grouped.head(20)
# Out:
# review_profilename  beer_name
# 0110x011            10 Commandments                            3.5
#                     15th Anniversary Wood Aged                 3.5
#                     21st Amendment IPA                         4.5
#                     90 Minute IPA                              5.0
#                     Adam                                       4.0
#                     AleSmith Decadence 2007 Imperial Porter    3.0
#                     AleSmith IPA                               5.0
#                     AleSmith My Bloody Valentine               5.0
#                     AleSmith Old Numbskull                     4.0
#                     AleSmith Speedway Stout                    4.5
#                     AleSmith Speedway Stout - Barrel Aged      3.5
#                     Allagash Odyssey                           4.5
#                     Alpha King Pale Ale                        5.0
#                     Alpha Klaus Christmas (Xmas) Porter        5.0
#                     Arctic Devil Barley Wine                   4.0
#                     Beatification                              5.0
#                     Bell's Expedition Stout                    4.0
#                     Bell's Hopslam Ale                         4.5
#                     Biere De Garde                             4.0
#                     Black Butte XX                             4.0
# Name: review_overall, dtype: float64

# %%
grouped = pd.DataFrame(grouped)
grouped = grouped.reset_index()
grouped.head()
# Out:
#   review_profilename                   beer_name  review_overall
# 0           0110x011             10 Commandments             3.5
# 1           0110x011  15th Anniversary Wood Aged             3.5
# 2           0110x011          21st Amendment IPA             4.5
# 3           0110x011               90 Minute IPA             5.0
# 4           0110x011                        Adam             4.0

# %%
user_reviews = grouped.pivot(index='review_profilename',columns='beer_name',values='review_overall')
#user_reviews = user_reviews.reset_index(drop = True)
user_reviews.head()
# Out:
# beer_name           "400" Ale  "Hop Obama" Ale  "Old Yeltsin" Imperial Stout  \
# review_profilename
# 0110x011                  NaN              NaN                           NaN
# 01Ryan10                  NaN              NaN                           NaN
# 02maxima                  NaN              NaN                           NaN
# 03SVTCobra                NaN              NaN                           NaN
# 04101Brewer               NaN              NaN                           NaN
#
# beer_name           "Shabadoo" Black & Tan Ale  \
# review_profilename
# 0110x011                                   NaN
# 01Ryan10                                   NaN
# 02maxima                                   NaN
# 03SVTCobra                                 NaN
# 04101Brewer                                NaN
#
# beer_name           "The Wind Cried Mari..." Scottish Heather Ale  \
# review_profilename
# 0110x011                                                      NaN
# 01Ryan10                                                      NaN
# 02maxima                                                      NaN
# 03SVTCobra                                                    NaN
# 04101Brewer                                                   NaN
#
# beer_name           "True Blue" Blueberry Ale  # 100  #'s Ale  #9  \
# review_profilename
# 0110x011                                  NaN    NaN      NaN NaN
# 01Ryan10                                  NaN    NaN      NaN NaN
# 02maxima                                  NaN    NaN      NaN NaN
# 03SVTCobra                                NaN    NaN      NaN NaN
# 04101Brewer                               NaN    NaN      NaN NaN
#
# beer_name           't Gaverhopke Extra                  ...                   \
# review_profilename                                       ...
# 0110x011                            NaN                  ...
# 01Ryan10                            NaN                  ...
# 02maxima                            NaN                  ...
# 03SVTCobra                          NaN                  ...
# 04101Brewer                         NaN                  ...
#
# beer_name           Épluche-Culotte  Équinoxe Du Printemps  Ölsch  \
# review_profilename
# 0110x011                        NaN                    NaN    NaN
# 01Ryan10                        NaN                    NaN    NaN
# 02maxima                        NaN                    NaN    NaN
# 03SVTCobra                      NaN                    NaN    NaN
# 04101Brewer                     NaN                    NaN    NaN
#
# beer_name           Ølfabrikken 100 Gram India Pale Ale  \
# review_profilename
# 0110x011                                            NaN
# 01Ryan10                                            NaN
# 02maxima                                            NaN
# 03SVTCobra                                          NaN
# 04101Brewer                                         NaN
#
# beer_name           Ølfabrikken Abbey Ale (Special Reserve)  \
# review_profilename
# 0110x011                                                NaN
# 01Ryan10                                                NaN
# 02maxima                                                NaN
# 03SVTCobra                                              NaN
# 04101Brewer                                             NaN
#
# beer_name           Ølfabrikken Kloster Jul  Ølfabrikken Porter  Über Alt  \
# review_profilename
# 0110x011                                NaN                 5.0       NaN
# 01Ryan10                                NaN                 NaN       NaN
# 02maxima                                NaN                 NaN       NaN
# 03SVTCobra                              NaN                 NaN       NaN
# 04101Brewer                             NaN                 NaN       NaN
#
# beer_name           Über Pils  ÜberSun (Imperial Summer Wheat Beer)
# review_profilename
# 0110x011                  NaN                                   NaN
# 01Ryan10                  NaN                                   NaN
# 02maxima                  NaN                                   NaN
# 03SVTCobra                NaN                                   NaN
# 04101Brewer               NaN                                   NaN
#
# [5 rows x 9768 columns]

# %%
counted = user_reviews.count(axis=1)
counted = pd.DataFrame(counted)

# %%
ten_reviews = counted.loc[(counted[0]>1) & (counted[0]<15)]

# %%
len(ten_reviews)
# Out:
# 13605

# %%
ten_reviews = ten_reviews.reset_index()

# %%
grouped_clean = pd.merge(ten_reviews, grouped, how = 'left', on = "review_profilename")

# %%
grouped_clean.head()
# Out:
#   review_profilename  0                             beer_name  review_overall
# 0           02maxima  4  Allagash Black - Bourbon Barrel Aged             4.0
# 1           02maxima  4                         Birra Moretti             3.0
# 2           02maxima  4        Brooklyn Black Chocolate Stout             4.5
# 3           02maxima  4                              Maharaja             4.5
# 4         03SVTCobra  3                       Lone Star Light             1.0

# %%
grouped_clean = grouped_clean.drop([0])

# %%
len(grouped_clean)
# Out:
# 68475

# %%
user_reviews_6 = grouped_clean.pivot(index='review_profilename',columns='beer_name',values='review_overall')
#user_reviews = user_reviews.reset_index(drop = True)
user_reviews_6.head()
# Out:
# beer_name           "400" Ale  "Hop Obama" Ale  "Old Yeltsin" Imperial Stout  \
# review_profilename
# 02maxima                  NaN              NaN                           NaN
# 03SVTCobra                NaN              NaN                           NaN
# 04101Brewer               NaN              NaN                           NaN
# 0beerguy0                 NaN              NaN                           NaN
# 0runkp0s                  NaN              NaN                           NaN
#
# beer_name           "Shabadoo" Black & Tan Ale  \
# review_profilename
# 02maxima                                   NaN
# 03SVTCobra                                 NaN
# 04101Brewer                                NaN
# 0beerguy0                                  NaN
# 0runkp0s                                   NaN
#
# beer_name           "The Wind Cried Mari..." Scottish Heather Ale  # 100  \
# review_profilename
# 02maxima                                                      NaN    NaN
# 03SVTCobra                                                    NaN    NaN
# 04101Brewer                                                   NaN    NaN
# 0beerguy0                                                     NaN    NaN
# 0runkp0s                                                      NaN    NaN
#
# beer_name           #'s Ale  #9  't Gaverhopke Extra  't Smisje BBBourgondier  \
# review_profilename
# 02maxima                NaN NaN                  NaN                      NaN
# 03SVTCobra              NaN NaN                  NaN                      NaN
# 04101Brewer             NaN NaN                  NaN                      NaN
# 0beerguy0               NaN NaN                  NaN                      NaN
# 0runkp0s                NaN NaN                  NaN                      NaN
#
# beer_name                           ...                   \
# review_profilename                  ...
# 02maxima                            ...
# 03SVTCobra                          ...
# 04101Brewer                         ...
# 0beerguy0                           ...
# 0runkp0s                            ...
#
# beer_name           Éphemère (Framboise)  Éphémère (Apple)  \
# review_profilename
# 02maxima                             NaN               NaN
# 03SVTCobra                           NaN               NaN
# 04101Brewer                          NaN               NaN
# 0beerguy0                            NaN               NaN
# 0runkp0s                             NaN               NaN
#
# beer_name           Éphémère (Cassis / Black Currant)  Éphémère (Cranberry)  \
# review_profilename
# 02maxima                                          NaN                   NaN
# 03SVTCobra                                        NaN                   NaN
# 04101Brewer                                       NaN                   NaN
# 0beerguy0                                         NaN                   NaN
# 0runkp0s                                          NaN                   NaN
#
# beer_name           Équinoxe Du Printemps  Ölsch  \
# review_profilename
# 02maxima                              NaN    NaN
# 03SVTCobra                            NaN    NaN
# 04101Brewer                           NaN    NaN
# 0beerguy0                             NaN    NaN
# 0runkp0s                              NaN    NaN
#
# beer_name           Ølfabrikken 100 Gram India Pale Ale  Ølfabrikken Porter  \
# review_profilename
# 02maxima                                            NaN                 NaN
# 03SVTCobra                                          NaN                 NaN
# 04101Brewer                                         NaN                 NaN
# 0beerguy0                                           NaN                 NaN
# 0runkp0s                                            NaN                 NaN
#
# beer_name           Über Pils  ÜberSun (Imperial Summer Wheat Beer)
# review_profilename
# 02maxima                  NaN                                   NaN
# 03SVTCobra                NaN                                   NaN
# 04101Brewer               NaN                                   NaN
# 0beerguy0                 NaN                                   NaN
# 0runkp0s                  NaN                                   NaN
#
# [5 rows x 7508 columns]

# %%
user_reviews_6.shape
# Out:
# (13605, 7508)

# %% [markdown]
# # Data Cleaning Dense Data

# %%
user_reviews = user_reviews_6

# %%
# Define Function to get the most rated movies
def get_most_rated_beers(user_reviews, max_number_of_beers):
    # 1- Count
    user_reviews = user_reviews.append(user_reviews.count(), ignore_index=True)
    # 2- sort
    user_reviews_sorted = user_reviews.sort_values(len(user_reviews)-1, axis=1, ascending=False)
    user_reviews_sorted = user_reviews_sorted.drop(user_reviews_sorted.tail(1).index)
    # 3- slice
    most_rated_beers = user_reviews_sorted.iloc[:, :max_number_of_beers]
    return most_rated_beers

# %%
def get_users_who_rate_the_most(user_reviews, max_number_of_beers):
    # Get most voting users
    # 1- Count
    user_reviews['counts'] = pd.Series(user_reviews.count(axis=1))
    # 2- Sort
    most_rated_beers_users = user_reviews.sort_values('counts', ascending=False)
    # 3- Slice
    most_rated_beers_users_selection = most_rated_beers_users.iloc[:max_number_of_beers, :]
    most_rated_beers_users_selection = most_rated_beers_users_selection.drop(['counts'], axis=1)
    return most_rated_beers_users_selection

# %%
# Define the sorting by rating function
# Define the sorting by rating function
def sort_by_rating_density(user_reviews, n_beers, n_users):
    most_rated_beers = get_most_rated_beers(user_reviews, n_beers)
    most_rated_beers = get_users_who_rate_the_most(most_rated_beers, n_users)
    return most_rated_beers
# choose the number of movies and users and sort
n_beers = 50
n_users = 30000
most_rated_beers_users_selection = sort_by_rating_density(user_reviews, n_beers, n_users)
# Print the result
#print(most_rated_beers_users_selection.head())

# %%
most_rated_beers_users_selection.head()
# Out:
# beer_name  90 Minute IPA  Old Rasputin Russian Imperial Stout  \
# 7228                 NaN                                  NaN
# 7149                 4.0                                  NaN
# 12505                NaN                                  NaN
# 12943                4.0                                  NaN
# 9947                 NaN                                  NaN
#
# beer_name  Pliny The Elder  Bell's Hopslam Ale  Sierra Nevada Pale Ale  \
# 7228                   5.0                 4.0                     NaN
# 7149                   NaN                 NaN                     5.0
# 12505                  NaN                 NaN                     NaN
# 12943                  NaN                 4.0                     NaN
# 9947                   NaN                 NaN                     NaN
#
# beer_name  Guinness Draught  Arrogant Bastard Ale  Duvel  \
# 7228                    NaN                   NaN    NaN
# 7149                    NaN                   4.5    4.5
# 12505                   NaN                   NaN    4.5
# 12943                   NaN                   NaN    4.0
# 9947                    NaN                   3.5    NaN
#
# beer_name  Sierra Nevada Celebration Ale  Two Hearted Ale     ...      \
# 7228                                 NaN              NaN     ...
# 7149                                 4.5              NaN     ...
# 12505                                NaN              NaN     ...
# 12943                                NaN              4.5     ...
# 9947                                 NaN              NaN     ...
#
# beer_name  Palo Santo Marron  Samuel Adams Octoberfest  Bud Light  #9  \
# 7228                     NaN                       NaN        5.0 NaN
# 7149                     NaN                       NaN        NaN NaN
# 12505                    NaN                       NaN        NaN NaN
# 12943                    NaN                       NaN        NaN NaN
# 9947                     NaN                       NaN        NaN NaN
#
# beer_name  Pumking  Bourbon County Brand Stout  Ayinger Celebrator Doppelbock  \
# 7228           NaN                         NaN                            NaN
# 7149           NaN                         NaN                            NaN
# 12505          5.0                         NaN                            NaN
# 12943          NaN                         NaN                            NaN
# 9947           NaN                         NaN                            NaN
#
# beer_name  Tröegs Nugget Nectar  Orval Trappist Ale  Punkin Ale
# 7228                        NaN                 NaN         NaN
# 7149                        NaN                 NaN        3.25
# 12505                       NaN                 NaN         NaN
# 12943                       4.0                 NaN         NaN
# 9947                        NaN                 NaN         NaN
#
# [5 rows x 50 columns]

# %%
len(most_rated_beers_users_selection)
# Out:
# 13605

# %%
most_rated_beers_users_selection.to_csv('test4.csv')

# %%
# Conversion to sparse csr matrix
sparse_ratings_dense = csr_matrix(pd.SparseDataFrame(most_rated_beers_users_selection).to_coo())

# %%
sparse_ratings_dense.shape
# Out:
# (13605, 50)

# %% [markdown]
# # Kmeans

# %%
Sum_of_squared_distances = []
K = range(1,35)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(sparse_ratings_dense)
    Sum_of_squared_distances.append(km.inertia_)

plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
# Create a kmeans model using k = 12
from sklearn.cluster import KMeans
model = KMeans(n_clusters=8, n_init = 5)

# Fit the model to the data
model.fit(sparse_ratings_dense)

# Use the data to predict the clusters
# save the predictions as `predicted_clusters`
predicted_clusters = model.predict(sparse_ratings_dense)

# %%
joblib.dump(model, 'model.pkl')  
model_loaded = joblib.load('model.pkl')

model_loaded
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=8, n_init=5, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
#load files for analysis
base = pd.read_csv("test7.csv", index_col='review_profilename')
test_sparse = csr_matrix(pd.SparseDataFrame(base).to_coo())

# %%
model_loaded.predict(test_sparse)
# Out:
# array([3])
