# %%
#correlation Matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

#load files for analysis
sample = pd.read_csv("AllListingsB.csv")
sample.columns
# Out:
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (3,6,7,24,25,26,27,28,29,49,53,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Index(['Unnamed: 0', 'accommodates', 'availability_30', 'availability_365',
#        'bathrooms', 'bed_type', 'bedrooms', 'beds',
#        'calculated_host_listings_count', 'cancellation_policy', 'city',
#        'cleaning_fee', 'country', 'first_review', 'extra_people',
#        'host_response_time', 'host_response_rate', 'host_is_superhost',
#        'host_since', 'instant_bookable', 'is_business_travel_ready',
#        'scrape_id', 'last_review', 'latitude', 'longitude', 'maximum_nights',
#        'minimum_nights', 'minimum_nights_avg_ntm', 'monthly_price',
#        'neighbourhood', 'number_of_reviews', 'number_of_reviews_ltm', 'price',
# ...

# %%
len(sample)
# Out:
# 1325841

# %%
#import numpy as np
#sample = linear.sample(n = 300000)

# %%
sample.bed_type.unique()
# Out:
# array(['Real Bed', 'Futon', 'Pull-out Sofa', 'Airbed', 'Couch', nan,
#        '292', '31', '22', '101', '34', '27', '11', '35', '44', '4', '0',
#        '2', '32', '6', '86', '159', '85', '155', '64', '14', '20', '7',
#        '23', '8', '5', '29', '45', '3', '1', '103', '17', '19', '259',
#        '28', '77', '203', '18', '137', '136', '176', '125', '110'],
#       dtype=object)

# %%
sample.cancellation_policy.unique()
# Out:
# array(['strict_14_with_grace_period', 'moderate', 'flexible',
#        'super_strict_30', 'super_strict_60', nan, 'strict',
#        'flexible_new', 'moderate_new', 'super_strict_30_new',
#        'strict_new', 'super_strict_60_new', 'luxury_super_strict_95',
#        'luxury_moderate', 'luxury_no_refund', 'luxury_super_strict_125'],
#       dtype=object)

# %%
sample.property_type.unique()
# Out:
# array(['Apartment', 'Townhouse', 'Houseboat', 'Bed and breakfast',
#        'Guest suite', 'Loft', 'Serviced apartment', 'House',
#        'Boutique hotel', 'Guesthouse', 'Boat', 'Condominium', 'Camper/RV',
#        'Chalet', 'Nature lodge', 'Tiny house', 'Other', 'Island', 'Hotel',
#        'Villa', 'Cabin', 'Bungalow', 'Hostel', 'Cottage', 'Dome house',
#        'Casa particular (Cuba)', 'Earth house', 'Barn', 'Aparthotel',
#        'Campsite', 'Tent', nan, 't', 'Yurt', 'Farm stay', 'Castle',
#        'Treehouse', 'Cave', 'Cycladic house (Greece)', 'In-law',
#        'Minsu (Taiwan)', 'Resort', 'Ryokan (Japan)', 'Bus', 'Tipi', 'Hut',
#        'Train', 'Vacation home', 'Heritage hotel (India)', 'Igloo',
#        'Dorm', 'Pension (South Korea)', 'Lighthouse',
#        "Shepherd's hut (U.K., France)", 'Condohotel', 'Timeshare',
#        'Windmill', '5', '2', '4', 'Pousada', 'Parking Space', 'Plane',
#        'Casa particular', 'Bed & Breakfast', 'Trullo (Italy)',
# ...

# %%
sample.review_scores_value.unique()
# Out:
# array([10.,  9.,  8., nan,  7.,  6.,  4.,  2.,  5.,  3.])

# %%
sample2 = sample[['smart_location', 'country', 'latitude', 'longitude','accommodates', 'availability_365', 'bathrooms', 'bedrooms', 'beds', 'calculated_host_listings_count',
                 'cleaning_fee','cancellation_policy','maximum_nights', 'minimum_nights', 'property_type', 'security_deposit','number_of_reviews_ltm',
                  'require_guest_phone_verification','requires_license','price','number_of_reviews','review_scores_value', 'review_scores_rating', 'guests_included','host_since', 'room_type', 'bed_type',
                 'weekly_price', 'monthly_price','extra_people', 'first_review','last_review', 'instant_bookable', 'require_guest_profile_picture','reviews_per_month',
                 'host_response_time', 'host_response_rate', 'host_is_superhost']]

# %%
sample2.head()
# Out:
#            smart_location      country  latitude longitude  accommodates  \
# 0  Amsterdam, Netherlands  Netherlands  52.36575   4.94142           2.0
# 1  Amsterdam, Netherlands  Netherlands  52.36509   4.89354           2.0
# 2  Amsterdam, Netherlands  Netherlands  52.37311   4.88367           3.0
# 3  Amsterdam, Netherlands  Netherlands  52.38673   4.89208           2.0
# 4  Amsterdam, Netherlands  Netherlands  52.37534   4.85729           2.0
#
#   availability_365  bathrooms bedrooms beds  calculated_host_listings_count  \
# 0               12        1.5        1    2                             1.0
# 1              166        1.0        1    1                             2.0
# 2              116        1.0        1    1                             2.0
# 3              102        1.0        1    1                             1.0
# 4              236        1.0        1    2                             1.0
#
# ...

# %%
sample2.dtypes
# Out:
# smart_location                       object
# country                              object
# latitude                            float64
# longitude                            object
# accommodates                        float64
# availability_365                     object
# bathrooms                           float64
# bedrooms                             object
# beds                                 object
# calculated_host_listings_count      float64
# cleaning_fee                         object
# cancellation_policy                  object
# maximum_nights                       object
# minimum_nights                       object
# property_type                        object
# security_deposit                     object
# number_of_reviews_ltm               float64
# require_guest_phone_verification     object
# requires_license                     object
# price                                object
# number_of_reviews                   float64
# ...

# %%
sample2['monthly_price'] = sample2['monthly_price'].astype(str).str.replace('$', '')
sample2['monthly_price'] = sample2['monthly_price'].astype(str).str.replace(',', '')
sample2['monthly_price'] = pd.to_numeric(sample2['monthly_price'], errors='coerce')
sample2.head()
# Out:
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
sample2['weekly_price'] = sample2['weekly_price'].astype(str).str.replace('$', '')
sample2['weekly_price'] = sample2['weekly_price'].astype(str).str.replace(',', '')
sample2['weekly_price'] = pd.to_numeric(sample2['weekly_price'], errors='coerce')
sample2.head()
# Out:
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
#sample2['security_deposit'] = sample2['security_deposit'].astype(str).str.replace('$', '')
#sample2['security_deposit'] = sample2['security_deposit'].astype(str).str.replace(',', '')
#sample2['security_deposit'] = pd.to_numeric(sample2['security_deposit'], errors='coerce')
#sample2.head()

# %%
sample2['extra_people'] = sample2['extra_people'].astype(str).str.replace('$', '')
sample2['extra_people'] = sample2['extra_people'].astype(str).str.replace(',', '')
sample2['extra_people'] = pd.to_numeric(sample2['extra_people'], errors='coerce')
sample2.head()
# Out:
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
sample2['price'] = sample2['price'].astype(str).str.replace('$', '')
sample2['price'] = sample2['price'].astype(str).str.replace(',', '')
# Out:
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
sample2['price'] = pd.to_numeric(sample2['price'], errors='coerce')
sample2.head()
# Out:
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#            smart_location      country  latitude longitude  accommodates  \
# 0  Amsterdam, Netherlands  Netherlands  52.36575   4.94142           2.0
# 1  Amsterdam, Netherlands  Netherlands  52.36509   4.89354           2.0
# 2  Amsterdam, Netherlands  Netherlands  52.37311   4.88367           3.0
# 3  Amsterdam, Netherlands  Netherlands  52.38673   4.89208           2.0
# 4  Amsterdam, Netherlands  Netherlands  52.37534   4.85729           2.0
#
#   availability_365  bathrooms bedrooms beds  calculated_host_listings_count  \
# ...

# %%
import numpy as np
sample2['pct_change'] = sample2.price.pct_change()
sample2['log_ret'] = np.log(sample2.price) - np.log(sample2.price.shift(1))
# Out:
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
sample2.head()
# Out:
#            smart_location      country  latitude longitude  accommodates  \
# 0  Amsterdam, Netherlands  Netherlands  52.36575   4.94142           2.0
# 1  Amsterdam, Netherlands  Netherlands  52.36509   4.89354           2.0
# 2  Amsterdam, Netherlands  Netherlands  52.37311   4.88367           3.0
# 3  Amsterdam, Netherlands  Netherlands  52.38673   4.89208           2.0
# 4  Amsterdam, Netherlands  Netherlands  52.37534   4.85729           2.0
#
#   availability_365  bathrooms bedrooms beds  calculated_host_listings_count  \
# 0               12        1.5        1    2                             1.0
# 1              166        1.0        1    1                             2.0
# 2              116        1.0        1    1                             2.0
# 3              102        1.0        1    1                             1.0
# 4              236        1.0        1    2                             1.0
#
#      ...    first_review last_review instant_bookable  \
# ...

# %%
#sample2.to_csv("sample2.csv", index = False, header=True)

# %%
sample2.dtypes
# Out:
# smart_location                       object
# country                              object
# latitude                            float64
# longitude                            object
# accommodates                        float64
# availability_365                     object
# bathrooms                           float64
# bedrooms                             object
# beds                                 object
# calculated_host_listings_count      float64
# cleaning_fee                         object
# cancellation_policy                  object
# maximum_nights                       object
# minimum_nights                       object
# property_type                        object
# security_deposit                     object
# number_of_reviews_ltm               float64
# require_guest_phone_verification     object
# requires_license                     object
# price                               float64
# number_of_reviews                   float64
# ...

# %%
sample2['availability_365'] = pd.to_numeric(sample2['availability_365'], errors='coerce')
sample2['bedrooms'] = pd.to_numeric(sample2['bedrooms'], errors='coerce')
sample2['beds'] = pd.to_numeric(sample2['beds'], errors='coerce')
sample2['maximum_nights'] = pd.to_numeric(sample2['maximum_nights'], errors='coerce')
sample2['minimum_nights'] = pd.to_numeric(sample2['minimum_nights'], errors='coerce')
sample2['longitude'] = pd.to_numeric(sample2['longitude'], errors='coerce')
# Out:
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
sample2.dtypes
# Out:
# smart_location                       object
# country                              object
# latitude                            float64
# longitude                           float64
# accommodates                        float64
# availability_365                    float64
# bathrooms                           float64
# bedrooms                            float64
# beds                                float64
# calculated_host_listings_count      float64
# cleaning_fee                         object
# cancellation_policy                  object
# maximum_nights                      float64
# minimum_nights                      float64
# property_type                        object
# security_deposit                     object
# number_of_reviews_ltm               float64
# require_guest_phone_verification     object
# requires_license                     object
# price                               float64
# number_of_reviews                   float64
# ...

# %%
sample2.head(15)
# Out:
#             smart_location      country  latitude  longitude  accommodates  \
# 0   Amsterdam, Netherlands  Netherlands  52.36575    4.94142           2.0
# 1   Amsterdam, Netherlands  Netherlands  52.36509    4.89354           2.0
# 2   Amsterdam, Netherlands  Netherlands  52.37311    4.88367           3.0
# 3   Amsterdam, Netherlands  Netherlands  52.38673    4.89208           2.0
# 4   Amsterdam, Netherlands  Netherlands  52.37534    4.85729           2.0
# 5   Amsterdam, Netherlands  Netherlands  52.36719    4.89092           2.0
# 6   Amsterdam, Netherlands  Netherlands  52.36773    4.89151           1.0
# 7   Amsterdam, Netherlands  Netherlands  52.35132    4.84838           4.0
# 8   Amsterdam, Netherlands  Netherlands  52.37565    4.87969           2.0
# 9   Amsterdam, Netherlands  Netherlands  52.37891    4.88321           2.0
# 10  Amsterdam, Netherlands  Netherlands  52.36781    4.89001           2.0
# ...

# %%
sample2.cancellation_policy.unique()
# Out:
# array(['strict_14_with_grace_period', 'moderate', 'flexible',
#        'super_strict_30', 'super_strict_60', nan, 'strict',
#        'flexible_new', 'moderate_new', 'super_strict_30_new',
#        'strict_new', 'super_strict_60_new', 'luxury_super_strict_95',
#        'luxury_moderate', 'luxury_no_refund', 'luxury_super_strict_125'],
#       dtype=object)

# %%
labels = sample2['cancellation_policy'].astype('category').cat.categories.tolist()
replace_map_comp = {'cancellation_policy' : {k: v for k,v in zip(labels,list(range(1,len(labels)+1)))}}
print(replace_map_comp)
#sample2['cancellation_cat'] = pd.get_dummies(sample2['cancellation_policy'])
# Out:
# {'cancellation_policy': {'flexible': 1, 'flexible_new': 2, 'luxury_moderate': 3, 'luxury_no_refund': 4, 'luxury_super_strict_125': 5, 'luxury_super_strict_95': 6, 'moderate': 7, 'moderate_new': 8, 'strict': 9, 'strict_14_with_grace_period': 10, 'strict_new': 11, 'super_strict_30': 12, 'super_strict_30_new': 13, 'super_strict_60': 14, 'super_strict_60_new': 15}}

# %%
sample2_replace = sample2.copy()

# %%
sample2_replace.replace(replace_map_comp, inplace=True)
sample2_replace.head()
# Out:
#            smart_location      country  latitude  longitude  accommodates  \
# 0  Amsterdam, Netherlands  Netherlands  52.36575    4.94142           2.0
# 1  Amsterdam, Netherlands  Netherlands  52.36509    4.89354           2.0
# 2  Amsterdam, Netherlands  Netherlands  52.37311    4.88367           3.0
# 3  Amsterdam, Netherlands  Netherlands  52.38673    4.89208           2.0
# 4  Amsterdam, Netherlands  Netherlands  52.37534    4.85729           2.0
#
#    availability_365  bathrooms  bedrooms  beds  \
# 0              12.0        1.5       1.0   2.0
# 1             166.0        1.0       1.0   1.0
# 2             116.0        1.0       1.0   1.0
# 3             102.0        1.0       1.0   1.0
# 4             236.0        1.0       1.0   2.0
#
#    calculated_host_listings_count    ...    first_review  last_review  \
# 0                             1.0    ...      2009-03-30   2019-04-17
# 1                             2.0    ...      2010-03-02   2019-04-24
# ...

# %%
sample2.property_type.unique()
# Out:
# array(['Apartment', 'Townhouse', 'Houseboat', 'Bed and breakfast',
#        'Guest suite', 'Loft', 'Serviced apartment', 'House',
#        'Boutique hotel', 'Guesthouse', 'Boat', 'Condominium', 'Camper/RV',
#        'Chalet', 'Nature lodge', 'Tiny house', 'Other', 'Island', 'Hotel',
#        'Villa', 'Cabin', 'Bungalow', 'Hostel', 'Cottage', 'Dome house',
#        'Casa particular (Cuba)', 'Earth house', 'Barn', 'Aparthotel',
#        'Campsite', 'Tent', nan, 't', 'Yurt', 'Farm stay', 'Castle',
#        'Treehouse', 'Cave', 'Cycladic house (Greece)', 'In-law',
#        'Minsu (Taiwan)', 'Resort', 'Ryokan (Japan)', 'Bus', 'Tipi', 'Hut',
#        'Train', 'Vacation home', 'Heritage hotel (India)', 'Igloo',
#        'Dorm', 'Pension (South Korea)', 'Lighthouse',
#        "Shepherd's hut (U.K., France)", 'Condohotel', 'Timeshare',
#        'Windmill', '5', '2', '4', 'Pousada', 'Parking Space', 'Plane',
#        'Casa particular', 'Bed & Breakfast', 'Trullo (Italy)',
# ...

# %%
labels2 = sample2['property_type'].astype('category').cat.categories.tolist()
replace_map_comp2 = {'property_type' : {k: v for k,v in zip(labels2,list(range(1,len(labels2)+1)))}}
print(replace_map_comp2)
# Out:
# {'property_type': {'2': 1, '4': 2, '5': 3, 'Aparthotel': 4, 'Apartment': 5, 'Barn': 6, 'Bed & Breakfast': 7, 'Bed and breakfast': 8, 'Boat': 9, 'Boutique hotel': 10, 'Bungalow': 11, 'Bus': 12, 'Cabin': 13, 'Camper/RV': 14, 'Campsite': 15, 'Casa particular': 16, 'Casa particular (Cuba)': 17, 'Castle': 18, 'Cave': 19, 'Chalet': 20, 'Condohotel': 21, 'Condominium': 22, 'Cottage': 23, 'Cycladic house': 24, 'Cycladic house (Greece)': 25, 'Dammuso': 26, 'Dammuso (Italy)': 27, 'Dome house': 28, 'Dorm': 29, 'Earth house': 30, 'Farm stay': 31, 'Guest suite': 32, 'Guesthouse': 33, 'Heritage hotel (India)': 34, 'Hostel': 35, 'Hotel': 36, 'House': 37, 'Houseboat': 38, 'Hut': 39, 'Igloo': 40, 'In-law': 41, 'Island': 42, 'Lighthouse': 43, 'Loft': 44, 'Minsu (Taiwan)': 45, 'Nature lodge': 46, 'Other': 47, 'Parking Space': 48, 'Pension (South Korea)': 49, 'Plane': 50, 'Pousada': 51, 'Resort': 52, 'Ryokan (Japan)': 53, 'Serviced apartment': 54, "Shepherd's hut (U.K., France)": 55, 'Tent': 56, 'Timesh
# ...

# %%
sample2_replace.replace(replace_map_comp2, inplace=True)
sample2_replace.head()
# Out:
#            smart_location      country  latitude  longitude  accommodates  \
# 0  Amsterdam, Netherlands  Netherlands  52.36575    4.94142           2.0
# 1  Amsterdam, Netherlands  Netherlands  52.36509    4.89354           2.0
# 2  Amsterdam, Netherlands  Netherlands  52.37311    4.88367           3.0
# 3  Amsterdam, Netherlands  Netherlands  52.38673    4.89208           2.0
# 4  Amsterdam, Netherlands  Netherlands  52.37534    4.85729           2.0
#
#    availability_365  bathrooms  bedrooms  beds  \
# 0              12.0        1.5       1.0   2.0
# 1             166.0        1.0       1.0   1.0
# 2             116.0        1.0       1.0   1.0
# 3             102.0        1.0       1.0   1.0
# 4             236.0        1.0       1.0   2.0
#
#    calculated_host_listings_count    ...    first_review  last_review  \
# 0                             1.0    ...      2009-03-30   2019-04-17
# 1                             2.0    ...      2010-03-02   2019-04-24
# ...

# %%
sample2.bed_type.unique()
# Out:
# array(['Real Bed', 'Futon', 'Pull-out Sofa', 'Airbed', 'Couch', nan,
#        '292', '31', '22', '101', '34', '27', '11', '35', '44', '4', '0',
#        '2', '32', '6', '86', '159', '85', '155', '64', '14', '20', '7',
#        '23', '8', '5', '29', '45', '3', '1', '103', '17', '19', '259',
#        '28', '77', '203', '18', '137', '136', '176', '125', '110'],
#       dtype=object)

# %%
labels4 = sample2['bed_type'].astype('category').cat.categories.tolist()
replace_map_comp4 = {'bed_type' : {k: v for k,v in zip(labels4,list(range(1,len(labels2)+1)))}}
print(replace_map_comp4)
# Out:
# {'bed_type': {'0': 1, '1': 2, '101': 3, '103': 4, '11': 5, '110': 6, '125': 7, '136': 8, '137': 9, '14': 10, '155': 11, '159': 12, '17': 13, '176': 14, '18': 15, '19': 16, '2': 17, '20': 18, '203': 19, '22': 20, '23': 21, '259': 22, '27': 23, '28': 24, '29': 25, '292': 26, '3': 27, '31': 28, '32': 29, '34': 30, '35': 31, '4': 32, '44': 33, '45': 34, '5': 35, '6': 36, '64': 37, '7': 38, '77': 39, '8': 40, '85': 41, '86': 42, 'Airbed': 43, 'Couch': 44, 'Futon': 45, 'Pull-out Sofa': 46, 'Real Bed': 47}}

# %%
sample2_replace.replace(replace_map_comp4, inplace=True)
sample2_replace.head()
# Out:
#            smart_location      country  latitude  longitude  accommodates  \
# 0  Amsterdam, Netherlands  Netherlands  52.36575    4.94142           2.0
# 1  Amsterdam, Netherlands  Netherlands  52.36509    4.89354           2.0
# 2  Amsterdam, Netherlands  Netherlands  52.37311    4.88367           3.0
# 3  Amsterdam, Netherlands  Netherlands  52.38673    4.89208           2.0
# 4  Amsterdam, Netherlands  Netherlands  52.37534    4.85729           2.0
#
#    availability_365  bathrooms  bedrooms  beds  \
# 0              12.0        1.5       1.0   2.0
# 1             166.0        1.0       1.0   1.0
# 2             116.0        1.0       1.0   1.0
# 3             102.0        1.0       1.0   1.0
# 4             236.0        1.0       1.0   2.0
#
#    calculated_host_listings_count    ...    first_review  last_review  \
# 0                             1.0    ...      2009-03-30   2019-04-17
# 1                             2.0    ...      2010-03-02   2019-04-24
# ...

# %%
sample2.room_type.unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room', nan, '13', '2',
#        '9', '25', '8', '0', '27', '7', '4', '5', '6', '3', '14', '20',
#        '11', '21', '12', '30', '16', '1', '19', '17', '15'], dtype=object)

# %%
labels3 = sample2['room_type'].astype('category').cat.categories.tolist()
replace_map_comp3 = {'room_type' : {k: v for k,v in zip(labels3,list(range(1,len(labels2)+1)))}}
print(replace_map_comp3)
# Out:
# {'room_type': {'0': 1, '1': 2, '11': 3, '12': 4, '13': 5, '14': 6, '15': 7, '16': 8, '17': 9, '19': 10, '2': 11, '20': 12, '21': 13, '25': 14, '27': 15, '3': 16, '30': 17, '4': 18, '5': 19, '6': 20, '7': 21, '8': 22, '9': 23, 'Entire home/apt': 24, 'Private room': 25, 'Shared room': 26}}

# %%
sample2_replace.replace(replace_map_comp3, inplace=True)
sample2_replace.head()
# Out:
#            smart_location      country  latitude  longitude  accommodates  \
# 0  Amsterdam, Netherlands  Netherlands  52.36575    4.94142           2.0
# 1  Amsterdam, Netherlands  Netherlands  52.36509    4.89354           2.0
# 2  Amsterdam, Netherlands  Netherlands  52.37311    4.88367           3.0
# 3  Amsterdam, Netherlands  Netherlands  52.38673    4.89208           2.0
# 4  Amsterdam, Netherlands  Netherlands  52.37534    4.85729           2.0
#
#    availability_365  bathrooms  bedrooms  beds  \
# 0              12.0        1.5       1.0   2.0
# 1             166.0        1.0       1.0   1.0
# 2             116.0        1.0       1.0   1.0
# 3             102.0        1.0       1.0   1.0
# 4             236.0        1.0       1.0   2.0
#
#    calculated_host_listings_count    ...    first_review  last_review  \
# 0                             1.0    ...      2009-03-30   2019-04-17
# 1                             2.0    ...      2010-03-02   2019-04-24
# ...

# %%
sample2_replace['room_type'] = pd.to_numeric(sample2_replace['room_type'], errors='coerce')

# %%
sample2.host_response_time.unique()
# Out:
# array(['within an hour', 'within a few hours', nan, 'within a day',
#        'a few days or more', 'f', 't', '6'], dtype=object)

# %%
labels6 = sample2['host_response_time'].astype('category').cat.categories.tolist()
replace_map_comp6 = {'host_response_time' : {k: v for k,v in zip(labels6,list(range(1,len(labels)+1)))}}
print(replace_map_comp)
# Out:
# {'cancellation_policy': {'flexible': 1, 'flexible_new': 2, 'luxury_moderate': 3, 'luxury_no_refund': 4, 'luxury_super_strict_125': 5, 'luxury_super_strict_95': 6, 'moderate': 7, 'moderate_new': 8, 'strict': 9, 'strict_14_with_grace_period': 10, 'strict_new': 11, 'super_strict_30': 12, 'super_strict_30_new': 13, 'super_strict_60': 14, 'super_strict_60_new': 15}}

# %%
sample2_replace.replace(replace_map_comp6, inplace=True)
sample2_replace.head()
# Out:
#            smart_location      country  latitude  longitude  accommodates  \
# 0  Amsterdam, Netherlands  Netherlands  52.36575    4.94142           2.0
# 1  Amsterdam, Netherlands  Netherlands  52.36509    4.89354           2.0
# 2  Amsterdam, Netherlands  Netherlands  52.37311    4.88367           3.0
# 3  Amsterdam, Netherlands  Netherlands  52.38673    4.89208           2.0
# 4  Amsterdam, Netherlands  Netherlands  52.37534    4.85729           2.0
#
#    availability_365  bathrooms  bedrooms  beds  \
# 0              12.0        1.5       1.0   2.0
# 1             166.0        1.0       1.0   1.0
# 2             116.0        1.0       1.0   1.0
# 3             102.0        1.0       1.0   1.0
# 4             236.0        1.0       1.0   2.0
#
#    calculated_host_listings_count    ...    first_review  last_review  \
# 0                             1.0    ...      2009-03-30   2019-04-17
# 1                             2.0    ...      2010-03-02   2019-04-24
# ...

# %%
sample2_replace['host_response_time'] = pd.to_numeric(sample2_replace['host_response_time'], errors='coerce')

# %%
sample2_replace['host_response_rate'] = sample2_replace['host_response_rate'].astype(str).str.replace('%', '')
sample2_replace['host_response_rate'] = pd.to_numeric(sample2_replace['host_response_rate'], errors='coerce')
sample2_replace.head()
# Out:
#            smart_location      country  latitude  longitude  accommodates  \
# 0  Amsterdam, Netherlands  Netherlands  52.36575    4.94142           2.0
# 1  Amsterdam, Netherlands  Netherlands  52.36509    4.89354           2.0
# 2  Amsterdam, Netherlands  Netherlands  52.37311    4.88367           3.0
# 3  Amsterdam, Netherlands  Netherlands  52.38673    4.89208           2.0
# 4  Amsterdam, Netherlands  Netherlands  52.37534    4.85729           2.0
#
#    availability_365  bathrooms  bedrooms  beds  \
# 0              12.0        1.5       1.0   2.0
# 1             166.0        1.0       1.0   1.0
# 2             116.0        1.0       1.0   1.0
# 3             102.0        1.0       1.0   1.0
# 4             236.0        1.0       1.0   2.0
#
#    calculated_host_listings_count    ...    first_review  last_review  \
# 0                             1.0    ...      2009-03-30   2019-04-17
# 1                             2.0    ...      2010-03-02   2019-04-24
# ...

# %%
sample2_replace['cleaning_fee'] = sample2_replace['cleaning_fee'].astype(str).str.replace('$', '')
sample2_replace['cleaning_fee'] = sample2_replace['cleaning_fee'].astype(str).str.replace(',', '')

# %%
sample2_replace['cleaning_fee'] = pd.to_numeric(sample2_replace['cleaning_fee'], errors='coerce')
sample2_replace.head()
# Out:
#            smart_location      country  latitude  longitude  accommodates  \
# 0  Amsterdam, Netherlands  Netherlands  52.36575    4.94142           2.0
# 1  Amsterdam, Netherlands  Netherlands  52.36509    4.89354           2.0
# 2  Amsterdam, Netherlands  Netherlands  52.37311    4.88367           3.0
# 3  Amsterdam, Netherlands  Netherlands  52.38673    4.89208           2.0
# 4  Amsterdam, Netherlands  Netherlands  52.37534    4.85729           2.0
#
#    availability_365  bathrooms  bedrooms  beds  \
# 0              12.0        1.5       1.0   2.0
# 1             166.0        1.0       1.0   1.0
# 2             116.0        1.0       1.0   1.0
# 3             102.0        1.0       1.0   1.0
# 4             236.0        1.0       1.0   2.0
#
#    calculated_host_listings_count    ...     first_review  last_review  \
# 0                             1.0    ...       2009-03-30   2019-04-17
# 1                             2.0    ...       2010-03-02   2019-04-24
# ...

# %%
sample2_replace['cleaning_fee'] = sample2_replace['cleaning_fee'].fillna(0)

# %%
sample2_replace.head()
# Out:
#            smart_location      country  latitude  longitude  accommodates  \
# 0  Amsterdam, Netherlands  Netherlands  52.36575    4.94142           2.0
# 1  Amsterdam, Netherlands  Netherlands  52.36509    4.89354           2.0
# 2  Amsterdam, Netherlands  Netherlands  52.37311    4.88367           3.0
# 3  Amsterdam, Netherlands  Netherlands  52.38673    4.89208           2.0
# 4  Amsterdam, Netherlands  Netherlands  52.37534    4.85729           2.0
#
#    availability_365  bathrooms  bedrooms  beds  \
# 0              12.0        1.5       1.0   2.0
# 1             166.0        1.0       1.0   1.0
# 2             116.0        1.0       1.0   1.0
# 3             102.0        1.0       1.0   1.0
# 4             236.0        1.0       1.0   2.0
#
#    calculated_host_listings_count    ...     first_review  last_review  \
# 0                             1.0    ...       2009-03-30   2019-04-17
# 1                             2.0    ...       2010-03-02   2019-04-24
# ...

# %%
sample2_replace['security_deposit'] = sample2_replace['security_deposit'].astype(str).str.replace('$', '')
sample2_replace['security_deposit'] = sample2_replace['security_deposit'].astype(str).str.replace(',', '')

# %%
sample2_replace['security_deposit'] = pd.to_numeric(sample2_replace['security_deposit'], errors='coerce')
sample2_replace['security_deposit'] = sample2_replace['security_deposit'].fillna(0)
sample2_replace.head()
# Out:
#            smart_location      country  latitude  longitude  accommodates  \
# 0  Amsterdam, Netherlands  Netherlands  52.36575    4.94142           2.0
# 1  Amsterdam, Netherlands  Netherlands  52.36509    4.89354           2.0
# 2  Amsterdam, Netherlands  Netherlands  52.37311    4.88367           3.0
# 3  Amsterdam, Netherlands  Netherlands  52.38673    4.89208           2.0
# 4  Amsterdam, Netherlands  Netherlands  52.37534    4.85729           2.0
#
#    availability_365  bathrooms  bedrooms  beds  \
# 0              12.0        1.5       1.0   2.0
# 1             166.0        1.0       1.0   1.0
# 2             116.0        1.0       1.0   1.0
# 3             102.0        1.0       1.0   1.0
# 4             236.0        1.0       1.0   2.0
#
#    calculated_host_listings_count    ...     first_review  last_review  \
# 0                             1.0    ...       2009-03-30   2019-04-17
# 1                             2.0    ...       2010-03-02   2019-04-24
# ...

# %%
sample2_replace.to_csv("cleaned_data.csv", index = False, header=True)

# %%
sample2_replace.isna().sum()
# Out:
# smart_location                         2968
# country                                2969
# latitude                               2968
# longitude                              2973
# accommodates                           2968
# availability_365                       2977
# bathrooms                              4344
# bedrooms                               3682
# beds                                   5557
# calculated_host_listings_count         3889
# cleaning_fee                              0
# cancellation_policy                    3030
# maximum_nights                         3024
# minimum_nights                         2978
# property_type                          2968
# security_deposit                          0
# number_of_reviews_ltm                  5731
# require_guest_phone_verification       3024
# requires_license                       3024
# price                                  3019
# number_of_reviews                      3019
# ...

# %%
len(sample2_replace)
# Out:
# 1325841

# %%
sample2_replace.columns
# Out:
# Index(['smart_location', 'country', 'latitude', 'longitude', 'accommodates',
#        'availability_365', 'bathrooms', 'bedrooms', 'beds',
#        'calculated_host_listings_count', 'cleaning_fee', 'cancellation_policy',
#        'maximum_nights', 'minimum_nights', 'property_type', 'security_deposit',
#        'number_of_reviews_ltm', 'require_guest_phone_verification',
#        'requires_license', 'price', 'number_of_reviews', 'review_scores_value',
#        'review_scores_rating', 'guests_included', 'host_since', 'room_type',
#        'bed_type', 'weekly_price', 'monthly_price', 'extra_people',
#        'first_review', 'last_review', 'instant_bookable',
#        'require_guest_profile_picture', 'reviews_per_month',
#        'host_response_time', 'host_response_rate', 'host_is_superhost',
#        'pct_change', 'log_ret'],
#       dtype='object')

# %%
sample2_replace.dtypes
# Out:
# smart_location                       object
# country                              object
# latitude                            float64
# longitude                           float64
# accommodates                        float64
# availability_365                    float64
# bathrooms                           float64
# bedrooms                            float64
# beds                                float64
# calculated_host_listings_count      float64
# cleaning_fee                        float64
# cancellation_policy                 float64
# maximum_nights                      float64
# minimum_nights                      float64
# property_type                       float64
# security_deposit                    float64
# number_of_reviews_ltm               float64
# require_guest_phone_verification     object
# requires_license                     object
# price                               float64
# number_of_reviews                   float64
# ...

# %%
sample2_replace.host_is_superhost.unique()
# Out:
# array(['t', 'f', nan, '2', '1', '3', '6', '4', '5', '3.0', '7', '16', '8'],
#       dtype=object)

# %%
sample2_replace['host_is_superhost'] = sample2_replace['host_is_superhost'].fillna('f')
sample2_replace['host_is_superhost'] = pd.get_dummies(sample2_replace['host_is_superhost'])
sample2_replace['host_is_superhost'] = pd.to_numeric(sample2_replace['host_is_superhost'], errors='coerce')

# %%
sample2_replace.instant_bookable.unique()
# Out:
# array(['t', 'f', nan], dtype=object)

# %%
sample2_replace['instant_bookable'] = sample2_replace['instant_bookable'].fillna('f')
sample2_replace['instant_bookable'] = pd.get_dummies(sample2_replace['instant_bookable'])
sample2_replace['instant_bookable'] = pd.to_numeric(sample2_replace['instant_bookable'], errors='coerce')

# %%
sample2_replace.require_guest_profile_picture.unique()
# Out:
# array(['f', 't', nan], dtype=object)

# %%
sample2_replace['require_guest_profile_picture'] = sample2_replace['require_guest_profile_picture'].fillna('f')
sample2_replace['require_guest_profile_picture'] = pd.get_dummies(sample2_replace['require_guest_profile_picture'])
sample2_replace['require_guest_profile_picture'] = pd.to_numeric(sample2_replace['require_guest_profile_picture'], errors='coerce')

# %%
sample2_replace.requires_license.unique()
# Out:
# array(['f', nan, 't'], dtype=object)

# %%
sample2_replace['require_guest_phone_verification'] = sample2_replace['require_guest_phone_verification'].fillna('f')

# %%
sample2_replace['require_guest_phone_verification'] = pd.get_dummies(sample2_replace['require_guest_phone_verification'])
sample2_replace['require_guest_phone_verification'] = pd.to_numeric(sample2_replace['require_guest_phone_verification'], errors='coerce')

# %%
#sample2_replace['require_guest_profile_picture'] = sample2_replace['require_guest_profile_picture'].fillna('f')

# %%
sample2_replace['requires_license'] = sample2_replace['requires_license'].fillna('f')

# %%
sample2_replace['requires_license'] = pd.get_dummies(sample2_replace['requires_license'])
sample2_replace['requires_license'] = pd.to_numeric(sample2_replace['requires_license'], errors='coerce')

# %%
#sample2_replace['host_has_profile_pic'] = sample2_replace['host_has_profile_pic'].fillna('f')

# %%
#sample2_replace['require_guest_phone_verification']  = pd.to_numeric(sample2_replace['require_guest_phone_verification'], errors='coerce')
#sample2_replace['require_guest_profile_picture']  = pd.to_numeric(sample2_replace['require_guest_profile_picture'], errors='coerce')
#sample2_replace['requires_license']  = pd.to_numeric(sample2_replace['requires_license'], errors='coerce')
#sample2_replace['host_has_profile_pic']  = pd.to_numeric(sample2_replace['host_has_profile_pic'], errors='coerce')
#sample2_replace['require_guest_phone_verification']  = pd.to_numeric(sample2_replace['require_guest_phone_verification'], errors='coerce')
#sample2_replace['require_guest_phone_verification']  = pd.to_numeric(sample2_replace['require_guest_phone_verification'], errors='coerce')

# %%
sample2_replace.dtypes
# Out:
# smart_location                       object
# country                              object
# latitude                            float64
# longitude                           float64
# accommodates                        float64
# availability_365                    float64
# bathrooms                           float64
# bedrooms                            float64
# beds                                float64
# calculated_host_listings_count      float64
# cleaning_fee                        float64
# cancellation_policy                 float64
# maximum_nights                      float64
# minimum_nights                      float64
# property_type                       float64
# security_deposit                    float64
# number_of_reviews_ltm               float64
# require_guest_phone_verification      uint8
# requires_license                      uint8
# price                               float64
# number_of_reviews                   float64
# ...

# %%
sample2_replace.isna().sum()
# Out:
# smart_location                         2968
# country                                2969
# latitude                               2968
# longitude                              2973
# accommodates                           2968
# availability_365                       2977
# bathrooms                              4344
# bedrooms                               3682
# beds                                   5557
# calculated_host_listings_count         3889
# cleaning_fee                              0
# cancellation_policy                    3030
# maximum_nights                         3024
# minimum_nights                         2978
# property_type                          2968
# security_deposit                          0
# number_of_reviews_ltm                  5731
# require_guest_phone_verification          0
# requires_license                          0
# price                                  3019
# number_of_reviews                      3019
# ...

# %%
len(sample2_replace)
# Out:
# 1325841

# %%
sample2_replace.longitude.unique()
# Out:
# array([  4.94142,   4.89354,   4.88367, ..., 115.85011, 115.74102,
#        115.71731])

# %%
sample.property_type.unique()
# Out:
# array(['Apartment', 'Townhouse', 'Houseboat', 'Bed and breakfast',
#        'Guest suite', 'Loft', 'Serviced apartment', 'House',
#        'Boutique hotel', 'Guesthouse', 'Boat', 'Condominium', 'Camper/RV',
#        'Chalet', 'Nature lodge', 'Tiny house', 'Other', 'Island', 'Hotel',
#        'Villa', 'Cabin', 'Bungalow', 'Hostel', 'Cottage', 'Dome house',
#        'Casa particular (Cuba)', 'Earth house', 'Barn', 'Aparthotel',
#        'Campsite', 'Tent', nan, 't', 'Yurt', 'Farm stay', 'Castle',
#        'Treehouse', 'Cave', 'Cycladic house (Greece)', 'In-law',
#        'Minsu (Taiwan)', 'Resort', 'Ryokan (Japan)', 'Bus', 'Tipi', 'Hut',
#        'Train', 'Vacation home', 'Heritage hotel (India)', 'Igloo',
#        'Dorm', 'Pension (South Korea)', 'Lighthouse',
#        "Shepherd's hut (U.K., France)", 'Condohotel', 'Timeshare',
#        'Windmill', '5', '2', '4', 'Pousada', 'Parking Space', 'Plane',
#        'Casa particular', 'Bed & Breakfast', 'Trullo (Italy)',
# ...

# %%
sample_cut = sample2_replace[['latitude', 'longitude','accommodates', 'availability_365', 'bathrooms', 'bedrooms', 'beds', 'calculated_host_listings_count',
                 'cleaning_fee','cancellation_policy','maximum_nights', 'minimum_nights', 'property_type', 'security_deposit','number_of_reviews_ltm',
                  'require_guest_phone_verification','requires_license','price','number_of_reviews','review_scores_value', 'review_scores_rating', 'guests_included',
                 'extra_people', 'instant_bookable', 'require_guest_profile_picture']]

# %%
sample_cut.columns
# Out:
# Index(['latitude', 'longitude', 'accommodates', 'availability_365',
#        'bathrooms', 'bedrooms', 'beds', 'calculated_host_listings_count',
#        'cleaning_fee', 'cancellation_policy', 'maximum_nights',
#        'minimum_nights', 'property_type', 'security_deposit',
#        'number_of_reviews_ltm', 'require_guest_phone_verification',
#        'requires_license', 'price', 'number_of_reviews', 'review_scores_value',
#        'review_scores_rating', 'guests_included', 'extra_people',
#        'instant_bookable', 'require_guest_profile_picture'],
#       dtype='object')

# %%
drop_na = sample_cut.dropna()
len(drop_na)
# Out:
# 962483

# %%
drop_na2 = drop_na.loc[drop_na['number_of_reviews_ltm'] > 7, :]
len(drop_na2)
# Out:
# 401222

# %%
sample2_replace.to_csv("cleaned_data_nona_8reviews_names.csv", index = False, header=True)

# %%
drop_na2.price.unique()
# Out:
# array([   59.,    80.,   150., ...,  1032.,   467., 11499.])

# %%
#make bins
bins = [0, 80, 100, 150, 200, 250, 500, 1000, 11499]
group_labels = ['<80', '81-100', '101-150', '151-200', '201-250', '251-500', '501-1000', '1,000-10000+']

# %%
#create sliced with pd.cut
sliced = pd.cut(drop_na['price'], bins, labels = group_labels)

# %%
drop_na2['Price_Group'] = sliced
drop_na2.head(5)
# Out:
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    latitude  longitude  accommodates  availability_365  bathrooms  bedrooms  \
# 0  52.36575    4.94142           2.0              12.0        1.5       1.0
# 1  52.36509    4.89354           2.0             166.0        1.0       1.0
# 3  52.38673    4.89208           2.0             102.0        1.0       1.0
# 4  52.37534    4.85729           2.0             236.0        1.0       1.0
# 6  52.36773    4.89151           1.0             166.0        1.0       1.0
#
#    beds  calculated_host_listings_count  cleaning_fee  cancellation_policy  \
# ...

# %%
labels7 = drop_na2['Price_Group'].astype('category').cat.categories.tolist()
replace_map_comp7 = {'Price_Group' : {k: v for k,v in zip(labels7,list(range(1,len(labels)+1)))}}
print(replace_map_comp7)
# Out:
# {'Price_Group': {'<80': 1, '81-100': 2, '101-150': 3, '151-200': 4, '201-250': 5, '251-500': 6, '501-1000': 7, '1,000-10000+': 8}}

# %%
drop_na2.replace(replace_map_comp7, inplace=True)
drop_na2.head()
# Out:
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:5821: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   regex=regex)
#    latitude  longitude  accommodates  availability_365  bathrooms  bedrooms  \
# 0  52.36575    4.94142           2.0              12.0        1.5       1.0
# 1  52.36509    4.89354           2.0             166.0        1.0       1.0
# 3  52.38673    4.89208           2.0             102.0        1.0       1.0
# 4  52.37534    4.85729           2.0             236.0        1.0       1.0
# 6  52.36773    4.89151           1.0             166.0        1.0       1.0
#
#    beds  calculated_host_listings_count  cleaning_fee  cancellation_policy  \
# ...

# %%
drop_na2.dtypes
# Out:
# latitude                            float64
# longitude                           float64
# accommodates                        float64
# availability_365                    float64
# bathrooms                           float64
# bedrooms                            float64
# beds                                float64
# calculated_host_listings_count      float64
# cleaning_fee                        float64
# cancellation_policy                 float64
# maximum_nights                      float64
# minimum_nights                      float64
# property_type                       float64
# security_deposit                    float64
# number_of_reviews_ltm               float64
# require_guest_phone_verification      uint8
# requires_license                      uint8
# price                               float64
# number_of_reviews                   float64
# review_scores_value                 float64
# review_scores_rating                float64
# ...

# %%
drop_na2.to_csv("cleaned_data_nona_7reviews.csv", index = False, header=True)

# %%
drop_na2['instant_bookable'] = drop_na2['instant_bookable'].astype(np.float64)
drop_na2['require_guest_phone_verification'] = drop_na2['require_guest_phone_verification'].astype(np.float64)
drop_na2['requires_license'] = drop_na2['requires_license'].astype(np.float64)
drop_na2['require_guest_profile_picture'] = drop_na2['require_guest_profile_picture'].astype(np.float64)
# Out:
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
drop_na2.dtypes
# Out:
# latitude                            float64
# longitude                           float64
# accommodates                        float64
# availability_365                    float64
# bathrooms                           float64
# bedrooms                            float64
# beds                                float64
# calculated_host_listings_count      float64
# cleaning_fee                        float64
# cancellation_policy                 float64
# maximum_nights                      float64
# minimum_nights                      float64
# property_type                       float64
# security_deposit                    float64
# number_of_reviews_ltm               float64
# require_guest_phone_verification    float64
# requires_license                    float64
# price                               float64
# number_of_reviews                   float64
# review_scores_value                 float64
# review_scores_rating                float64
# ...
